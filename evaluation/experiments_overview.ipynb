# %%
from evaluation_utils import read_processed_shards
from constants import MODE_2_3_MARG_PROCESSED_DIR, MODE_2_3_MARG_2_PROCESSED_DIR
import os
import torch
import matplotlib.pyplot as plt

# %%
loss = torch.nn.MarginRankingLoss(margin=5, reduction='mean')

l = []
l2 = []
s = [i for i in range(-10, 20)]
for i in s:
    pos, neg, ones = torch.tensor([i]), torch.tensor([5]), torch.tensor([1])
    # l += [loss(pos, neg, ones)]

    d = lambda x: 1/(1+torch.exp(-x))
    l += [max(d(pos) - d(neg) + 1/2 , 0)] # WRONG LOSS
    # l2 += [(1-torch.log(pos))-torch.log(neg)]
plt.plot(s, l)
# plt.plot(s, l2)

# %%
l[0]
# Out:
# torch.return_types.max(
# values=tensor(-14.5000),
# indices=tensor(0))

# %%
df_1 = read_processed_shards(MODE_2_3_MARG_PROCESSED_DIR)
df_2 = read_processed_shards(MODE_2_3_MARG_2_PROCESSED_DIR)
# Out:
# 1.ndjson
# 2.ndjson
# 3.ndjson
# 4.ndjson
# 5.ndjson
# 6.ndjson
# 7.ndjson
# 8.ndjson
# 9.ndjson
# 10.ndjson
# 11.ndjson
# 12.ndjson
# 13.ndjson
# 14.ndjson
# 15.ndjson
# 16.ndjson
# 17.ndjson
# 18.ndjson
# 19.ndjson
# 20.ndjson
# 21.ndjson
# 22.ndjson
# 23.ndjson
# 24.ndjson
# concatenating
# 1.ndjson
# 2.ndjson
# 3.ndjson
# 4.ndjson
# 5.ndjson
# 6.ndjson
# concatenating

# %%
df_1 = df_1.astype({ 'marginal_param': 'string'}).astype({ 'marginal_param': 'category' })
df_2 = df_2.astype({ 'marginal_param': 'string'}).astype({ 'marginal_param': 'category' })
params_1 = df_1.groupby('marginal_param').count()
params_2 = df_2.groupby('marginal_param').count()

N_SAMPLES_GOAL = 2_000

# %%
params_1
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree']                                  1582        1582
# ['cluster_size_slope']                           673         673
# ['feature_center_distance']                      680         680
# ['min_degree']                                  1670        1670
# ['num_clusters']                                1760        1760
# ['nvertex']                                     4080        4080
# ['p_to_q_ratio', 'feature_center_distance']       20          20
# ['p_to_q_ratio']                                1564        1564
# ['power_exponent']                              2337        2337
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree']                                                  1582
# ['cluster_size_slope']                                           673
# ['feature_center_distance']                                      680
# ['min_degree']                                                  1670
# ['num_clusters']                                                1760
# ['nvertex']                                                     4080
# ['p_to_q_ratio', 'feature_center_distance']                       20
# ['p_to_q_ratio']                                                1564
# ['power_exponent']                                              2337
#
#                                              feature_dim  \
# marginal_param
# ['avg_degree']                                      1582
# ['cluster_size_slope']                               673
# ['feature_center_distance']                          680
# ['min_degree']                                      1670
# ['num_clusters']                                    1760
# ['nvertex']                                         4080
# ['p_to_q_ratio', 'feature_center_distance']           20
# ['p_to_q_ratio']                                    1564
# ['power_exponent']                                  2337
#
#                                              edge_center_distance  \
# marginal_param
# ['avg_degree']                                               1582
# ['cluster_size_slope']                                        673
# ['feature_center_distance']                                   680
# ['min_degree']                                               1670
# ['num_clusters']                                             1760
# ['nvertex']                                                  4080
# ['p_to_q_ratio', 'feature_center_distance']                    20
# ['p_to_q_ratio']                                             1564
# ['power_exponent']                                           2337
#
#                                              edge_feature_dim  p_to_q_ratio  \
# marginal_param
# ['avg_degree']                                           1582          1582
# ['cluster_size_slope']                                    673           673
# ['feature_center_distance']                               680           680
# ['min_degree']                                           1670          1670
# ['num_clusters']                                         1760          1760
# ['nvertex']                                              4080          4080
# ['p_to_q_ratio', 'feature_center_distance']                20            20
# ['p_to_q_ratio']                                         1564          1564
# ['power_exponent']                                       2337          2337
#
#                                              num_clusters  cluster_size_slope  \
# marginal_param
# ['avg_degree']                                       1582                1582
# ['cluster_size_slope']                                673                 673
# ['feature_center_distance']                           680                 680
# ['min_degree']                                       1670                1670
# ['num_clusters']                                     1760                1760
# ['nvertex']                                          4080                4080
# ['p_to_q_ratio', 'feature_center_distance']            20                  20
# ['p_to_q_ratio']                                     1564                1564
# ['power_exponent']                                   2337                2337
#
#                                              power_exponent  ...  \
# marginal_param                                               ...
# ['avg_degree']                                         1582  ...
# ['cluster_size_slope']                                  673  ...
# ['feature_center_distance']                             680  ...
# ['min_degree']                                         1670  ...
# ['num_clusters']                                       1760  ...
# ['nvertex']                                            4080  ...
# ['p_to_q_ratio', 'feature_center_distance']              20  ...
# ['p_to_q_ratio']                                       1564  ...
# ['power_exponent']                                     2337  ...
#
#                                              GIN_MVMI_FT_URL_train_patience  \
# marginal_param
# ['avg_degree']                                                         1582
# ['cluster_size_slope']                                                  673
# ['feature_center_distance']                                             680
# ['min_degree']                                                         1670
# ['num_clusters']                                                       1760
# ['nvertex']                                                            4080
# ['p_to_q_ratio', 'feature_center_distance']                              20
# ['p_to_q_ratio']                                                       1564
# ['power_exponent']                                                     2337
#
#                                              GIN_MVMI_FT_URL_encoder_in_channels  \
# marginal_param
# ['avg_degree']                                                              1582
# ['cluster_size_slope']                                                       673
# ['feature_center_distance']                                                  680
# ['min_degree']                                                              1670
# ['num_clusters']                                                            1760
# ['nvertex']                                                                 4080
# ['p_to_q_ratio', 'feature_center_distance']                                   20
# ['p_to_q_ratio']                                                            1564
# ['power_exponent']                                                          2337
#
#                                              GIN_MVMI_FT_URL_encoder_hidden_channels  \
# marginal_param
# ['avg_degree']                                                                  1582
# ['cluster_size_slope']                                                           673
# ['feature_center_distance']                                                      680
# ['min_degree']                                                                  1670
# ['num_clusters']                                                                1760
# ['nvertex']                                                                     4080
# ['p_to_q_ratio', 'feature_center_distance']                                       20
# ['p_to_q_ratio']                                                                1564
# ['power_exponent']                                                              2337
#
#                                              GIN_MVMI_FT_URL_encoder_num_layers  \
# marginal_param
# ['avg_degree']                                                             1582
# ['cluster_size_slope']                                                      673
# ['feature_center_distance']                                                 680
# ['min_degree']                                                             1670
# ['num_clusters']                                                           1760
# ['nvertex']                                                                4080
# ['p_to_q_ratio', 'feature_center_distance']                                  20
# ['p_to_q_ratio']                                                           1564
# ['power_exponent']                                                         2337
#
#                                              GIN_MVMI_FT_URL_encoder_dropout  \
# marginal_param
# ['avg_degree']                                                          1582
# ['cluster_size_slope']                                                   673
# ['feature_center_distance']                                              680
# ['min_degree']                                                          1670
# ['num_clusters']                                                        1760
# ['nvertex']                                                             4080
# ['p_to_q_ratio', 'feature_center_distance']                               20
# ['p_to_q_ratio']                                                        1564
# ['power_exponent']                                                      2337
#
#                                              GIN_MVMI_FT_URL_encoder_out_channels  \
# marginal_param
# ['avg_degree']                                                               1582
# ['cluster_size_slope']                                                        673
# ['feature_center_distance']                                                   680
# ['min_degree']                                                               1670
# ['num_clusters']                                                             1760
# ['nvertex']                                                                  4080
# ['p_to_q_ratio', 'feature_center_distance']                                    20
# ['p_to_q_ratio']                                                             1564
# ['power_exponent']                                                           2337
#
#                                              GIN_MVMI_FT_URL_pretext_common_representation_regularization  \
# marginal_param
# ['avg_degree']                                                                            1582
# ['cluster_size_slope']                                                                     673
# ['feature_center_distance']                                                                680
# ['min_degree']                                                                            1670
# ['num_clusters']                                                                          1760
# ['nvertex']                                                                               4080
# ['p_to_q_ratio', 'feature_center_distance']                                                 20
# ['p_to_q_ratio']                                                                          1564
# ['power_exponent']                                                                        2337
#
#                                              GIN_MVMI_FT_URL_pretext_disagreement_regularization  \
# marginal_param
# ['avg_degree']                                                                            1582
# ['cluster_size_slope']                                                                     673
# ['feature_center_distance']                                                                680
# ['min_degree']                                                                            1670
# ['num_clusters']                                                                          1760
# ['nvertex']                                                                               4080
# ['p_to_q_ratio', 'feature_center_distance']                                                 20
# ['p_to_q_ratio']                                                                          1564
# ['power_exponent']                                                                        2337
#
#                                              GIN_MVMI_FT_URL_pretext_k  \
# marginal_param
# ['avg_degree']                                                    1582
# ['cluster_size_slope']                                             673
# ['feature_center_distance']                                        680
# ['min_degree']                                                    1670
# ['num_clusters']                                                  1760
# ['nvertex']                                                       4080
# ['p_to_q_ratio', 'feature_center_distance']                         20
# ['p_to_q_ratio']                                                  1564
# ['power_exponent']                                                2337
#
#                                              GIN_MVMI_FT_URL_skipped
# marginal_param
# ['avg_degree']                                                  1582
# ['cluster_size_slope']                                           673
# ['feature_center_distance']                                      680
# ['min_degree']                                                  1670
# ['num_clusters']                                                1760
# ['nvertex']                                                     4080
# ['p_to_q_ratio', 'feature_center_distance']                       20
# ['p_to_q_ratio']                                                1564
# ['power_exponent']                                              2337
#
# [9 rows x 4533 columns]

# %%
N_SAMPLES_GOAL - params_1
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree']                                   418         418
# ['cluster_size_slope']                          1327        1327
# ['feature_center_distance']                     1320        1320
# ['min_degree']                                   330         330
# ['num_clusters']                                 240         240
# ['nvertex']                                    -2080       -2080
# ['p_to_q_ratio', 'feature_center_distance']     1980        1980
# ['p_to_q_ratio']                                 436         436
# ['power_exponent']                              -337        -337
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree']                                                   418
# ['cluster_size_slope']                                          1327
# ['feature_center_distance']                                     1320
# ['min_degree']                                                   330
# ['num_clusters']                                                 240
# ['nvertex']                                                    -2080
# ['p_to_q_ratio', 'feature_center_distance']                     1980
# ['p_to_q_ratio']                                                 436
# ['power_exponent']                                              -337
#
#                                              feature_dim  \
# marginal_param
# ['avg_degree']                                       418
# ['cluster_size_slope']                              1327
# ['feature_center_distance']                         1320
# ['min_degree']                                       330
# ['num_clusters']                                     240
# ['nvertex']                                        -2080
# ['p_to_q_ratio', 'feature_center_distance']         1980
# ['p_to_q_ratio']                                     436
# ['power_exponent']                                  -337
#
#                                              edge_center_distance  \
# marginal_param
# ['avg_degree']                                                418
# ['cluster_size_slope']                                       1327
# ['feature_center_distance']                                  1320
# ['min_degree']                                                330
# ['num_clusters']                                              240
# ['nvertex']                                                 -2080
# ['p_to_q_ratio', 'feature_center_distance']                  1980
# ['p_to_q_ratio']                                              436
# ['power_exponent']                                           -337
#
#                                              edge_feature_dim  p_to_q_ratio  \
# marginal_param
# ['avg_degree']                                            418           418
# ['cluster_size_slope']                                   1327          1327
# ['feature_center_distance']                              1320          1320
# ['min_degree']                                            330           330
# ['num_clusters']                                          240           240
# ['nvertex']                                             -2080         -2080
# ['p_to_q_ratio', 'feature_center_distance']              1980          1980
# ['p_to_q_ratio']                                          436           436
# ['power_exponent']                                       -337          -337
#
#                                              num_clusters  cluster_size_slope  \
# marginal_param
# ['avg_degree']                                        418                 418
# ['cluster_size_slope']                               1327                1327
# ['feature_center_distance']                          1320                1320
# ['min_degree']                                        330                 330
# ['num_clusters']                                      240                 240
# ['nvertex']                                         -2080               -2080
# ['p_to_q_ratio', 'feature_center_distance']          1980                1980
# ['p_to_q_ratio']                                      436                 436
# ['power_exponent']                                   -337                -337
#
#                                              power_exponent  ...  \
# marginal_param                                               ...
# ['avg_degree']                                          418  ...
# ['cluster_size_slope']                                 1327  ...
# ['feature_center_distance']                            1320  ...
# ['min_degree']                                          330  ...
# ['num_clusters']                                        240  ...
# ['nvertex']                                           -2080  ...
# ['p_to_q_ratio', 'feature_center_distance']            1980  ...
# ['p_to_q_ratio']                                        436  ...
# ['power_exponent']                                     -337  ...
#
#                                              GIN_MVMI_FT_URL_train_patience  \
# marginal_param
# ['avg_degree']                                                          418
# ['cluster_size_slope']                                                 1327
# ['feature_center_distance']                                            1320
# ['min_degree']                                                          330
# ['num_clusters']                                                        240
# ['nvertex']                                                           -2080
# ['p_to_q_ratio', 'feature_center_distance']                            1980
# ['p_to_q_ratio']                                                        436
# ['power_exponent']                                                     -337
#
#                                              GIN_MVMI_FT_URL_encoder_in_channels  \
# marginal_param
# ['avg_degree']                                                               418
# ['cluster_size_slope']                                                      1327
# ['feature_center_distance']                                                 1320
# ['min_degree']                                                               330
# ['num_clusters']                                                             240
# ['nvertex']                                                                -2080
# ['p_to_q_ratio', 'feature_center_distance']                                 1980
# ['p_to_q_ratio']                                                             436
# ['power_exponent']                                                          -337
#
#                                              GIN_MVMI_FT_URL_encoder_hidden_channels  \
# marginal_param
# ['avg_degree']                                                                   418
# ['cluster_size_slope']                                                          1327
# ['feature_center_distance']                                                     1320
# ['min_degree']                                                                   330
# ['num_clusters']                                                                 240
# ['nvertex']                                                                    -2080
# ['p_to_q_ratio', 'feature_center_distance']                                     1980
# ['p_to_q_ratio']                                                                 436
# ['power_exponent']                                                              -337
#
#                                              GIN_MVMI_FT_URL_encoder_num_layers  \
# marginal_param
# ['avg_degree']                                                              418
# ['cluster_size_slope']                                                     1327
# ['feature_center_distance']                                                1320
# ['min_degree']                                                              330
# ['num_clusters']                                                            240
# ['nvertex']                                                               -2080
# ['p_to_q_ratio', 'feature_center_distance']                                1980
# ['p_to_q_ratio']                                                            436
# ['power_exponent']                                                         -337
#
#                                              GIN_MVMI_FT_URL_encoder_dropout  \
# marginal_param
# ['avg_degree']                                                           418
# ['cluster_size_slope']                                                  1327
# ['feature_center_distance']                                             1320
# ['min_degree']                                                           330
# ['num_clusters']                                                         240
# ['nvertex']                                                            -2080
# ['p_to_q_ratio', 'feature_center_distance']                             1980
# ['p_to_q_ratio']                                                         436
# ['power_exponent']                                                      -337
#
#                                              GIN_MVMI_FT_URL_encoder_out_channels  \
# marginal_param
# ['avg_degree']                                                                418
# ['cluster_size_slope']                                                       1327
# ['feature_center_distance']                                                  1320
# ['min_degree']                                                                330
# ['num_clusters']                                                              240
# ['nvertex']                                                                 -2080
# ['p_to_q_ratio', 'feature_center_distance']                                  1980
# ['p_to_q_ratio']                                                              436
# ['power_exponent']                                                           -337
#
#                                              GIN_MVMI_FT_URL_pretext_common_representation_regularization  \
# marginal_param
# ['avg_degree']                                                                             418
# ['cluster_size_slope']                                                                    1327
# ['feature_center_distance']                                                               1320
# ['min_degree']                                                                             330
# ['num_clusters']                                                                           240
# ['nvertex']                                                                              -2080
# ['p_to_q_ratio', 'feature_center_distance']                                               1980
# ['p_to_q_ratio']                                                                           436
# ['power_exponent']                                                                        -337
#
#                                              GIN_MVMI_FT_URL_pretext_disagreement_regularization  \
# marginal_param
# ['avg_degree']                                                                             418
# ['cluster_size_slope']                                                                    1327
# ['feature_center_distance']                                                               1320
# ['min_degree']                                                                             330
# ['num_clusters']                                                                           240
# ['nvertex']                                                                              -2080
# ['p_to_q_ratio', 'feature_center_distance']                                               1980
# ['p_to_q_ratio']                                                                           436
# ['power_exponent']                                                                        -337
#
#                                              GIN_MVMI_FT_URL_pretext_k  \
# marginal_param
# ['avg_degree']                                                     418
# ['cluster_size_slope']                                            1327
# ['feature_center_distance']                                       1320
# ['min_degree']                                                     330
# ['num_clusters']                                                   240
# ['nvertex']                                                      -2080
# ['p_to_q_ratio', 'feature_center_distance']                       1980
# ['p_to_q_ratio']                                                   436
# ['power_exponent']                                                -337
#
#                                              GIN_MVMI_FT_URL_skipped
# marginal_param
# ['avg_degree']                                                   418
# ['cluster_size_slope']                                          1327
# ['feature_center_distance']                                     1320
# ['min_degree']                                                   330
# ['num_clusters']                                                 240
# ['nvertex']                                                    -2080
# ['p_to_q_ratio', 'feature_center_distance']                     1980
# ['p_to_q_ratio']                                                 436
# ['power_exponent']                                              -337
#
# [9 rows x 4533 columns]

# %%
params_2
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree', 'feature_center_distance']        440         440
# ['num_clusters', 'avg_degree']                   380         380
# ['num_clusters', 'feature_center_distance']     1600        1600
# ['p_to_q_ratio', 'avg_degree']                  1000        1000
# ['p_to_q_ratio', 'feature_center_distance']      990         990
# ['p_to_q_ratio', 'num_clusters']                1000        1000
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                        440
# ['num_clusters', 'avg_degree']                                   380
# ['num_clusters', 'feature_center_distance']                     1600
# ['p_to_q_ratio', 'avg_degree']                                  1000
# ['p_to_q_ratio', 'feature_center_distance']                      990
# ['p_to_q_ratio', 'num_clusters']                                1000
#
#                                              feature_dim  \
# marginal_param
# ['avg_degree', 'feature_center_distance']            440
# ['num_clusters', 'avg_degree']                       380
# ['num_clusters', 'feature_center_distance']         1600
# ['p_to_q_ratio', 'avg_degree']                      1000
# ['p_to_q_ratio', 'feature_center_distance']          990
# ['p_to_q_ratio', 'num_clusters']                    1000
#
#                                              edge_center_distance  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                     440
# ['num_clusters', 'avg_degree']                                380
# ['num_clusters', 'feature_center_distance']                  1600
# ['p_to_q_ratio', 'avg_degree']                               1000
# ['p_to_q_ratio', 'feature_center_distance']                   990
# ['p_to_q_ratio', 'num_clusters']                             1000
#
#                                              edge_feature_dim  p_to_q_ratio  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                 440           440
# ['num_clusters', 'avg_degree']                            380           380
# ['num_clusters', 'feature_center_distance']              1600          1600
# ['p_to_q_ratio', 'avg_degree']                           1000          1000
# ['p_to_q_ratio', 'feature_center_distance']               990           990
# ['p_to_q_ratio', 'num_clusters']                         1000          1000
#
#                                              num_clusters  cluster_size_slope  \
# marginal_param
# ['avg_degree', 'feature_center_distance']             440                 440
# ['num_clusters', 'avg_degree']                        380                 380
# ['num_clusters', 'feature_center_distance']          1600                1600
# ['p_to_q_ratio', 'avg_degree']                       1000                1000
# ['p_to_q_ratio', 'feature_center_distance']           990                 990
# ['p_to_q_ratio', 'num_clusters']                     1000                1000
#
#                                              power_exponent  ...  \
# marginal_param                                               ...
# ['avg_degree', 'feature_center_distance']               440  ...
# ['num_clusters', 'avg_degree']                          380  ...
# ['num_clusters', 'feature_center_distance']            1600  ...
# ['p_to_q_ratio', 'avg_degree']                         1000  ...
# ['p_to_q_ratio', 'feature_center_distance']             990  ...
# ['p_to_q_ratio', 'num_clusters']                       1000  ...
#
#                                              GIN_MVMI_FT_URL_train_patience  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                               440
# ['num_clusters', 'avg_degree']                                          380
# ['num_clusters', 'feature_center_distance']                            1600
# ['p_to_q_ratio', 'avg_degree']                                         1000
# ['p_to_q_ratio', 'feature_center_distance']                             990
# ['p_to_q_ratio', 'num_clusters']                                       1000
#
#                                              GIN_MVMI_FT_URL_encoder_in_channels  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                    440
# ['num_clusters', 'avg_degree']                                               380
# ['num_clusters', 'feature_center_distance']                                 1600
# ['p_to_q_ratio', 'avg_degree']                                              1000
# ['p_to_q_ratio', 'feature_center_distance']                                  990
# ['p_to_q_ratio', 'num_clusters']                                            1000
#
#                                              GIN_MVMI_FT_URL_encoder_hidden_channels  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                        440
# ['num_clusters', 'avg_degree']                                                   380
# ['num_clusters', 'feature_center_distance']                                     1600
# ['p_to_q_ratio', 'avg_degree']                                                  1000
# ['p_to_q_ratio', 'feature_center_distance']                                      990
# ['p_to_q_ratio', 'num_clusters']                                                1000
#
#                                              GIN_MVMI_FT_URL_encoder_num_layers  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                   440
# ['num_clusters', 'avg_degree']                                              380
# ['num_clusters', 'feature_center_distance']                                1600
# ['p_to_q_ratio', 'avg_degree']                                             1000
# ['p_to_q_ratio', 'feature_center_distance']                                 990
# ['p_to_q_ratio', 'num_clusters']                                           1000
#
#                                              GIN_MVMI_FT_URL_encoder_dropout  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                440
# ['num_clusters', 'avg_degree']                                           380
# ['num_clusters', 'feature_center_distance']                             1600
# ['p_to_q_ratio', 'avg_degree']                                          1000
# ['p_to_q_ratio', 'feature_center_distance']                              990
# ['p_to_q_ratio', 'num_clusters']                                        1000
#
#                                              GIN_MVMI_FT_URL_encoder_out_channels  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                     440
# ['num_clusters', 'avg_degree']                                                380
# ['num_clusters', 'feature_center_distance']                                  1600
# ['p_to_q_ratio', 'avg_degree']                                               1000
# ['p_to_q_ratio', 'feature_center_distance']                                   990
# ['p_to_q_ratio', 'num_clusters']                                             1000
#
#                                              GIN_MVMI_FT_URL_pretext_common_representation_regularization  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                                  440
# ['num_clusters', 'avg_degree']                                                             380
# ['num_clusters', 'feature_center_distance']                                               1600
# ['p_to_q_ratio', 'avg_degree']                                                            1000
# ['p_to_q_ratio', 'feature_center_distance']                                                990
# ['p_to_q_ratio', 'num_clusters']                                                          1000
#
#                                              GIN_MVMI_FT_URL_pretext_disagreement_regularization  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                                  440
# ['num_clusters', 'avg_degree']                                                             380
# ['num_clusters', 'feature_center_distance']                                               1600
# ['p_to_q_ratio', 'avg_degree']                                                            1000
# ['p_to_q_ratio', 'feature_center_distance']                                                990
# ['p_to_q_ratio', 'num_clusters']                                                          1000
#
#                                              GIN_MVMI_FT_URL_pretext_k  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                          440
# ['num_clusters', 'avg_degree']                                     380
# ['num_clusters', 'feature_center_distance']                       1600
# ['p_to_q_ratio', 'avg_degree']                                    1000
# ['p_to_q_ratio', 'feature_center_distance']                        990
# ['p_to_q_ratio', 'num_clusters']                                  1000
#
#                                              GIN_MVMI_FT_URL_skipped
# marginal_param
# ['avg_degree', 'feature_center_distance']                        440
# ['num_clusters', 'avg_degree']                                   380
# ['num_clusters', 'feature_center_distance']                     1600
# ['p_to_q_ratio', 'avg_degree']                                  1000
# ['p_to_q_ratio', 'feature_center_distance']                      990
# ['p_to_q_ratio', 'num_clusters']                                1000
#
# [6 rows x 4533 columns]

# %%
N_SAMPLES_GOAL - params_2
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree', 'feature_center_distance']       1560        1560
# ['num_clusters', 'avg_degree']                  1620        1620
# ['num_clusters', 'feature_center_distance']      400         400
# ['p_to_q_ratio', 'avg_degree']                  1000        1000
# ['p_to_q_ratio', 'feature_center_distance']     1010        1010
# ['p_to_q_ratio', 'num_clusters']                1000        1000
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                       1560
# ['num_clusters', 'avg_degree']                                  1620
# ['num_clusters', 'feature_center_distance']                      400
# ['p_to_q_ratio', 'avg_degree']                                  1000
# ['p_to_q_ratio', 'feature_center_distance']                     1010
# ['p_to_q_ratio', 'num_clusters']                                1000
#
#                                              feature_dim  \
# marginal_param
# ['avg_degree', 'feature_center_distance']           1560
# ['num_clusters', 'avg_degree']                      1620
# ['num_clusters', 'feature_center_distance']          400
# ['p_to_q_ratio', 'avg_degree']                      1000
# ['p_to_q_ratio', 'feature_center_distance']         1010
# ['p_to_q_ratio', 'num_clusters']                    1000
#
#                                              edge_center_distance  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                    1560
# ['num_clusters', 'avg_degree']                               1620
# ['num_clusters', 'feature_center_distance']                   400
# ['p_to_q_ratio', 'avg_degree']                               1000
# ['p_to_q_ratio', 'feature_center_distance']                  1010
# ['p_to_q_ratio', 'num_clusters']                             1000
#
#                                              edge_feature_dim  p_to_q_ratio  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                1560          1560
# ['num_clusters', 'avg_degree']                           1620          1620
# ['num_clusters', 'feature_center_distance']               400           400
# ['p_to_q_ratio', 'avg_degree']                           1000          1000
# ['p_to_q_ratio', 'feature_center_distance']              1010          1010
# ['p_to_q_ratio', 'num_clusters']                         1000          1000
#
#                                              num_clusters  cluster_size_slope  \
# marginal_param
# ['avg_degree', 'feature_center_distance']            1560                1560
# ['num_clusters', 'avg_degree']                       1620                1620
# ['num_clusters', 'feature_center_distance']           400                 400
# ['p_to_q_ratio', 'avg_degree']                       1000                1000
# ['p_to_q_ratio', 'feature_center_distance']          1010                1010
# ['p_to_q_ratio', 'num_clusters']                     1000                1000
#
#                                              power_exponent  ...  \
# marginal_param                                               ...
# ['avg_degree', 'feature_center_distance']              1560  ...
# ['num_clusters', 'avg_degree']                         1620  ...
# ['num_clusters', 'feature_center_distance']             400  ...
# ['p_to_q_ratio', 'avg_degree']                         1000  ...
# ['p_to_q_ratio', 'feature_center_distance']            1010  ...
# ['p_to_q_ratio', 'num_clusters']                       1000  ...
#
#                                              GIN_MVMI_FT_URL_train_patience  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                              1560
# ['num_clusters', 'avg_degree']                                         1620
# ['num_clusters', 'feature_center_distance']                             400
# ['p_to_q_ratio', 'avg_degree']                                         1000
# ['p_to_q_ratio', 'feature_center_distance']                            1010
# ['p_to_q_ratio', 'num_clusters']                                       1000
#
#                                              GIN_MVMI_FT_URL_encoder_in_channels  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                   1560
# ['num_clusters', 'avg_degree']                                              1620
# ['num_clusters', 'feature_center_distance']                                  400
# ['p_to_q_ratio', 'avg_degree']                                              1000
# ['p_to_q_ratio', 'feature_center_distance']                                 1010
# ['p_to_q_ratio', 'num_clusters']                                            1000
#
#                                              GIN_MVMI_FT_URL_encoder_hidden_channels  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                       1560
# ['num_clusters', 'avg_degree']                                                  1620
# ['num_clusters', 'feature_center_distance']                                      400
# ['p_to_q_ratio', 'avg_degree']                                                  1000
# ['p_to_q_ratio', 'feature_center_distance']                                     1010
# ['p_to_q_ratio', 'num_clusters']                                                1000
#
#                                              GIN_MVMI_FT_URL_encoder_num_layers  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                  1560
# ['num_clusters', 'avg_degree']                                             1620
# ['num_clusters', 'feature_center_distance']                                 400
# ['p_to_q_ratio', 'avg_degree']                                             1000
# ['p_to_q_ratio', 'feature_center_distance']                                1010
# ['p_to_q_ratio', 'num_clusters']                                           1000
#
#                                              GIN_MVMI_FT_URL_encoder_dropout  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                               1560
# ['num_clusters', 'avg_degree']                                          1620
# ['num_clusters', 'feature_center_distance']                              400
# ['p_to_q_ratio', 'avg_degree']                                          1000
# ['p_to_q_ratio', 'feature_center_distance']                             1010
# ['p_to_q_ratio', 'num_clusters']                                        1000
#
#                                              GIN_MVMI_FT_URL_encoder_out_channels  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                    1560
# ['num_clusters', 'avg_degree']                                               1620
# ['num_clusters', 'feature_center_distance']                                   400
# ['p_to_q_ratio', 'avg_degree']                                               1000
# ['p_to_q_ratio', 'feature_center_distance']                                  1010
# ['p_to_q_ratio', 'num_clusters']                                             1000
#
#                                              GIN_MVMI_FT_URL_pretext_common_representation_regularization  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                                 1560
# ['num_clusters', 'avg_degree']                                                            1620
# ['num_clusters', 'feature_center_distance']                                                400
# ['p_to_q_ratio', 'avg_degree']                                                            1000
# ['p_to_q_ratio', 'feature_center_distance']                                               1010
# ['p_to_q_ratio', 'num_clusters']                                                          1000
#
#                                              GIN_MVMI_FT_URL_pretext_disagreement_regularization  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                                                 1560
# ['num_clusters', 'avg_degree']                                                            1620
# ['num_clusters', 'feature_center_distance']                                                400
# ['p_to_q_ratio', 'avg_degree']                                                            1000
# ['p_to_q_ratio', 'feature_center_distance']                                               1010
# ['p_to_q_ratio', 'num_clusters']                                                          1000
#
#                                              GIN_MVMI_FT_URL_pretext_k  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                         1560
# ['num_clusters', 'avg_degree']                                    1620
# ['num_clusters', 'feature_center_distance']                        400
# ['p_to_q_ratio', 'avg_degree']                                    1000
# ['p_to_q_ratio', 'feature_center_distance']                       1010
# ['p_to_q_ratio', 'num_clusters']                                  1000
#
#                                              GIN_MVMI_FT_URL_skipped
# marginal_param
# ['avg_degree', 'feature_center_distance']                       1560
# ['num_clusters', 'avg_degree']                                  1620
# ['num_clusters', 'feature_center_distance']                      400
# ['p_to_q_ratio', 'avg_degree']                                  1000
# ['p_to_q_ratio', 'feature_center_distance']                     1010
# ['p_to_q_ratio', 'num_clusters']                                1000
#
# [6 rows x 4533 columns]
