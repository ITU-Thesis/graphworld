# %%
from evaluation_utils import read_processed_shards
from constants import MODE_2_3_MARG_PROCESSED_DIR, MODE_2_3_MARG_2_PROCESSED_DIR
import os
import torch
import matplotlib.pyplot as plt

# %%
df_1 = read_processed_shards(MODE_2_3_MARG_PROCESSED_DIR)
df_2 = read_processed_shards(MODE_2_3_MARG_2_PROCESSED_DIR)
# Out:
# 1.ndjson
# 2.ndjson
# 3.ndjson
# 4.ndjson
# 5.ndjson
# 6.ndjson
# 7.ndjson
# 8.ndjson
# 9.ndjson
# 10.ndjson
# 11.ndjson
# 12.ndjson
# 13.ndjson
# 14.ndjson
# 15.ndjson
# 16.ndjson
# 17.ndjson
# 18.ndjson
# 19.ndjson
# 20.ndjson
# 21.ndjson
# 22.ndjson
# 23.ndjson
# 24.ndjson
# 25.ndjson
# 26.ndjson
# 27.ndjson
# 28.ndjson
# 29.ndjson
# 30.ndjson
# 31.ndjson
# 32.ndjson
# 33.ndjson
# 34.ndjson
# 35.ndjson
# concatenating
# 1.ndjson
# 2.ndjson
# 3.ndjson
# 4.ndjson
# 5.ndjson
# 6.ndjson
# 7.ndjson
# 8.ndjson
# 9.ndjson
# 10.ndjson
# 11.ndjson
# 12.ndjson
# 13.ndjson
# 14.ndjson
# concatenating

# %%
df_1 = df_1.astype({ 'marginal_param': 'string'}).astype({ 'marginal_param': 'category' })
df_2 = df_2.astype({ 'marginal_param': 'string'}).astype({ 'marginal_param': 'category' })
params_1 = df_1.groupby('marginal_param').count()
params_2 = df_2.groupby('marginal_param').count()

N_SAMPLES_GOAL = 2_000

# %%
params_1
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree']                                  2000        2000
# ['cluster_size_slope']                          1873        1873
# ['feature_center_distance']                     2820        2820
# ['min_deg']                                      655         655
# ['min_degree']                                  2000        2000
# ['num_clusters']                                2000        2000
# ['nvertex']                                     4080        4080
# ['p_to_q_ratio', 'feature_center_distance']       20          20
# ['p_to_q_ratio']                                2000        2000
# ['power_exponent']                              2337        2337
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree']                                                  2000
# ['cluster_size_slope']                                          1873
# ...

# %%
N_SAMPLES_GOAL - params_1
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree']                                     0           0
# ['cluster_size_slope']                           127         127
# ['feature_center_distance']                     -820        -820
# ['min_deg']                                     1345        1345
# ['min_degree']                                     0           0
# ['num_clusters']                                   0           0
# ['nvertex']                                    -2080       -2080
# ['p_to_q_ratio', 'feature_center_distance']     1980        1980
# ['p_to_q_ratio']                                   0           0
# ['power_exponent']                              -337        -337
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree']                                                     0
# ['cluster_size_slope']                                           127
# ...

# %%
params_2
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree', 'feature_center_distance']       1910        1910
# ['num_clusters', 'avg_degree']                  2700        2700
# ['num_clusters', 'feature_center_distance']     2000        2000
# ['p_to_q_ratio', 'avg_degree']                  2000        2000
# ['p_to_q_ratio', 'feature_center_distance']     1970        1970
# ['p_to_q_ratio', 'num_clusters']                2000        2000
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                       1910
# ['num_clusters', 'avg_degree']                                  2700
# ['num_clusters', 'feature_center_distance']                     2000
# ['p_to_q_ratio', 'avg_degree']                                  2000
# ['p_to_q_ratio', 'feature_center_distance']                     1970
# ...

# %%
N_SAMPLES_GOAL - params_2
# Out:
#                                              nvertex  avg_degree  \
# marginal_param
# ['avg_degree', 'feature_center_distance']         90          90
# ['num_clusters', 'avg_degree']                  -700        -700
# ['num_clusters', 'feature_center_distance']        0           0
# ['p_to_q_ratio', 'avg_degree']                     0           0
# ['p_to_q_ratio', 'feature_center_distance']       30          30
# ['p_to_q_ratio', 'num_clusters']                   0           0
#
#                                              feature_center_distance  \
# marginal_param
# ['avg_degree', 'feature_center_distance']                         90
# ['num_clusters', 'avg_degree']                                  -700
# ['num_clusters', 'feature_center_distance']                        0
# ['p_to_q_ratio', 'avg_degree']                                     0
# ['p_to_q_ratio', 'feature_center_distance']                       30
# ...
