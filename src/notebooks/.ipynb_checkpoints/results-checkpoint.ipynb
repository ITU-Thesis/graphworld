# %%
# Imports
import json
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Constants
NSHARDS = 10
RESULTS_DIR = '/tmp/mwe'
LOCALDIR = '/tmp'

ENCODERS = ['GCN', 'GAT', 'GIN', 'GAT']
TRAINING_SCHEMES = ['JL', 'PF', 'URL']
SSL_METHODS = ['DeepGraphInfomax','MERIT', 'GBT', 'SelfGNNPPR', 'BGRL','GCA', 'PairwiseAttrSim', 'CentralityScoreRanking', 'AttributeMask']

METRIC = 'test_rocauc_ovr'

# %%
dfs = []
for shard_idx in range(NSHARDS):
  filename = 'results.ndjson-%s-of-%s' % (str(shard_idx).zfill(5), str(NSHARDS).zfill(5))
  print(filename)

  with open(f'{RESULTS_DIR}/{filename}', 'r') as f:
    lines = f.readlines()
    records = map(json.loads, lines)
    dfs.append(pd.DataFrame.from_records(records))

# Construct df and remove nans
results_df = pd.concat(dfs)
results_df.drop(['marginal_param', 'fixed_params'], axis=1, inplace=True)
results_df.dropna(axis=0, inplace=True)
del dfs
# Out:
# results.ndjson-00000-of-00010
# results.ndjson-00001-of-00010
# results.ndjson-00002-of-00010
# results.ndjson-00003-of-00010
# results.ndjson-00004-of-00010
# results.ndjson-00005-of-00010
# results.ndjson-00006-of-00010
# results.ndjson-00007-of-00010
# results.ndjson-00008-of-00010
# results.ndjson-00009-of-00010

# %%
results_df
# Out:
#    nvertex  avg_degree  feature_center_distance  feature_dim  \
# 0      159   10.805032                 2.904477           16
#
#    edge_center_distance  edge_feature_dim  p_to_q_ratio  num_clusters  \
# 0                   2.0                 2     42.980519             4
#
#    cluster_size_slope  power_exponent  ...  APPNP_MERIT_URL_encoder_dropout  \
# 0            0.766012             3.0  ...                              0.8
#
#   APPNP_MERIT_URL_encoder_out_channels  \
# 0                                    4
#
#    APPNP_MERIT_URL_pretext_edge_modification_ratio  \
# 0                                              0.4
#
#    APPNP_MERIT_URL_pretext_feature_mask_ratio  APPNP_MERIT_URL_pretext_beta  \
# 0                                         0.1                           0.7
#
#    APPNP_MERIT_URL_pretext_alpha  \
# 0                            0.3
#
#                       APPNP_MERIT_URL_pretext_losses  \
# 0  [5.556436538696289, 5.556929111480713, 5.55446...
#
#                APPNP_MERIT_URL_downstream_val_losses  \
# 0  [17.2080858707428, 17.002153730392457, 15.4126...
#
#              APPNP_MERIT_URL_downstream_train_losses  \
# 0  [1.4225412607192993, 1.4215384721755981, 1.418...
#
#        APPNP_MERIT_URL_downstream_val_tuning_metrics
# 0  [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, ...
#
# [1 rows x 523 columns]

# %%
def get_cells(dataframe: pd.DataFrame, encoder:str = "", ssl_method:str = "", training_scheme:str = "", other:str = ""):
    cols = [col for col in dataframe if (encoder in col and ssl_method in col 
                                         and training_scheme in col and other in col)]
    return dataframe[cols]

# %%
get_cells(results_df, training_scheme="PF", other="train")
# Out:
#    GCN_SelfGNNSplit_PF_train_pretext_epochs  \
# 0                                       200
#
#    GCN_SelfGNNSplit_PF_train_pretext_lr  \
# 0                                 0.001
#
#    GCN_SelfGNNSplit_PF_train_downstream_epochs  \
# 0                                          200
#
#    GCN_SelfGNNSplit_PF_train_downstream_lr  \
# 0                                    0.001
#
#          GCN_SelfGNNSplit_PF_downstream_train_losses  \
# 0  [1.5123919248580933, 1.4970430135726929, 1.482...
#
#    GCN_SelfGNNPPR_PF_train_pretext_epochs  GCN_SelfGNNPPR_PF_train_pretext_lr  \
# 0                                     200                               0.001
#
#    GCN_SelfGNNPPR_PF_train_downstream_epochs  \
# 0                                        200
#
#    GCN_SelfGNNPPR_PF_train_downstream_lr  \
# 0                                  0.001
#
#            GCN_SelfGNNPPR_PF_downstream_train_losses  ...  \
# 0  [1.4406156539916992, 1.461792230606079, 1.3993...  ...
#
#    GCN_MERIT_PF_train_pretext_epochs  GCN_MERIT_PF_train_pretext_lr  \
# 0                                200                          0.001
#
#    GCN_MERIT_PF_train_downstream_epochs  GCN_MERIT_PF_train_downstream_lr  \
# 0                                   200                             0.001
#
#                 GCN_MERIT_PF_downstream_train_losses  \
# 0  [1.2402170896530151, 1.1826224327087402, 1.174...
#
#    APPNP_MERIT_PF_train_pretext_epochs  APPNP_MERIT_PF_train_pretext_lr  \
# 0                                  200                            0.001
#
#    APPNP_MERIT_PF_train_downstream_epochs  APPNP_MERIT_PF_train_downstream_lr  \
# 0                                     200                               0.001
#
#               APPNP_MERIT_PF_downstream_train_losses
# 0  [1.5552564859390259, 1.5404798984527588, 1.518...
#
# [1 rows x 30 columns]

# %%
def plot_learning_curve(df: pd.DataFrame, training_scheme:str, encoder:str, ssl_method:str):
    metrics = ["pretext_losses", "downstream_train_losses", "downstream_val_losses", "downstream_val_tuning_metrics"]
    colors = ["r","g","b","purple"]
    fig, axes = plt.subplots(1, 4, figsize=(15, 2))
    for idx, m in enumerate(metrics):
        cell = get_cells(df, encoder=encoder, training_scheme=training_scheme, ssl_method=ssl_method, other=m).iloc[0,0]
        axes[idx].plot(cell, label=f'{encoder}_{ssl_method}_{training_scheme}_{m}', c=colors[idx])
    fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2),
          ncol=4, fancybox=True, shadow=True)
    fig.show()

# %%
for ts in TRAINING_SCHEMES:
    plot_learning_curve(df = results_df, training_scheme = ts, encoder="GCN", ssl_method=SSL_METHODS[0])

# %%
for ts in TRAINING_SCHEMES:
    plot_learning_curve(df = results_df, training_scheme = ts, encoder="GAT", ssl_method=SSL_METHODS[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-703a3f1ef904> in <module>
#       1 for ts in TRAINING_SCHEMES:
# ----> 2     plot_learning_curve(df = results_df, training_scheme = ts, encoder="GAT", ssl_method=SSL_METHODS[0])
#
# <ipython-input-24-a0fdca9c6bcb> in plot_learning_curve(df, training_scheme, encoder, ssl_method)
#       4     fig, axes = plt.subplots(1, 4, figsize=(15, 2))
#       5     for idx, m in enumerate(metrics):
# ----> 6         cell = get_cells(df, encoder=encoder, training_scheme=training_scheme, ssl_method=ssl_method, other=m).iloc[0,0]
#       7         axes[idx].plot(cell, label=f'{encoder}_{ssl_method}_{training_scheme}_{m}', c=colors[idx])
#       8     fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2),
#
# /opt/venv/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /opt/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# /opt/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#     704                 raise ValueError(
#
# /opt/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1350             return
#    1351         elif is_integer(key):
# -> 1352             self._validate_integer(key, axis)
#    1353         elif isinstance(key, tuple):
#    1354             # a tuple should already have been caught by this point
#
# /opt/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
for ts in TRAINING_SCHEMES:
    plot_learning_curve(df = results_df, training_scheme = ts, encoder="GIN", ssl_method=SSL_METHODS[0])

# %%
for ts in TRAINING_SCHEMES:
    plot_learning_curve(df = results_df, training_scheme = ts, encoder="APPNP", ssl_method=SSL_METHODS[0])

# %%
# Function for 1D lineplot
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

def bucket_response_surface1d(results_df, xvar, metric='test_accuracy',
                              group=False, ngrid=25, custom_range=None):
  # BAD_VALS = [np.nan, np.inf, -np.inf]
  # results_df_inner = results_df[~results_df.isin(BAD_VALS).any(1)]
  results_df_inner = results_df.copy(deep=True)
  if custom_range is None:
    min_xvar = np.min(results_df_inner[xvar])
    max_xvar = np.max(results_df_inner[xvar])
  else:
    min_xvar = custom_range[0]
    max_xvar = custom_range[1]
  xrange = np.linspace(min_xvar, max_xvar, ngrid)
  def convert_value(z, range):
    return range[np.argmin(np.abs(range - z))]
  results_df_inner[xvar] = results_df_inner[xvar].apply(convert_value,
                                                        range=xrange)
  if group:
    return results_df_inner.groupby([xvar])[[xvar, metric]].mean()
  else:
    return results_df_inner

def plot_response_surface1d(param, metric, results_df,
                            models=MODELS,
                            reverse_x=False, ci=99):
  bucketed_dfs = []
  index_pos = 0
  grouped_index_pos = 0
  grouped_bucketed_dfs = []
  for model in models:
    model_metric = '%s_%s' % (model, metric)
    if model_metric not in results_df.columns:
      continue

    # Get and store ungrouped bucketed df
    bucketed_df = bucket_response_surface1d(results_df, param,
                                            metric=model_metric,
                                            group=False)
    bucketed_df = bucketed_df.rename(columns={model_metric: metric})
    bucketed_df['model'] = model
    new_index = list(range(index_pos, index_pos + bucketed_df.shape[0]))
    bucketed_df.index = new_index
    bucketed_dfs.append(bucketed_df)
    index_pos += bucketed_df.shape[0]

    # Get and store grouped bucketed df
    grouped_bucketed_df = bucket_response_surface1d(results_df, param,
                                                    metric=model_metric,
                                                    group=True)
    grouped_bucketed_df = grouped_bucketed_df.rename(
        columns={model_metric: metric})
    grouped_bucketed_df['model'] = model
    grouped_new_index = list(range(
        grouped_index_pos, grouped_index_pos + grouped_bucketed_df.shape[0]))
    grouped_bucketed_df.index = grouped_new_index
    grouped_bucketed_dfs.append(grouped_bucketed_df)
    grouped_index_pos += grouped_bucketed_df.shape[0]

    
    
  plot_df = pd.concat(bucketed_dfs, axis=0)

  # Make the plot
  fig = plt.figure(figsize=(10, 10))

  range_x = (np.min(results_df[param]), np.max(results_df[param]))
  if reverse_x:
    range_x = (range_x[1], range_x[0])

  sns.lineplot(data=plot_df, x=param, y=metric, hue="model", ci=ci)
  plt.title('%s vs %s' % (metric, param))
  plt.show()

# %%
results_df
# Out:
#    nvertex  avg_degree  feature_center_distance  feature_dim  \
# 0      209   10.899522                 3.492671           16
# 0      225    9.733334                 3.158847           16
# 0      376   10.224000                 3.940170           16
# 0      497   12.443548                 1.045569           16
# 0      331   10.308157                 1.027807           16
# 0      281   12.469751                 4.209970           16
# 0      318    9.465409                 1.019629           16
# 0      153   10.130719                 3.534509           16
# 0      194   11.195876                 2.374508           16
# 0      231   12.761905                 2.016350           16
#
#    edge_center_distance  edge_feature_dim  p_to_q_ratio  num_clusters  \
# 0                   2.0                 2     22.221548             4
# 0                   2.0                 2     50.454397             4
# 0                   2.0                 2     31.935628             4
# 0                   2.0                 2     39.164808             4
# 0                   2.0                 2      2.569559             4
# 0                   2.0                 2     15.307312             4
# 0                   2.0                 2     22.591605             4
# 0                   2.0                 2     28.795572             4
# 0                   2.0                 2      8.771916             4
# 0                   2.0                 2      5.594774             4
#
#    cluster_size_slope  power_exponent  ...  GCN__test_rocauc_ovo  \
# 0            0.011599             3.0  ...              0.599011
# 0            0.469266             3.0  ...              0.684683
# 0            0.007042             3.0  ...              0.500000
# 0            0.496077             3.0  ...              0.956830
# 0            0.411158             3.0  ...              0.500000
# 0            0.016430             3.0  ...              0.946697
# 0            0.630220             3.0  ...              0.960115
# 0            0.252313             3.0  ...              1.000000
# 0            0.069010             3.0  ...              0.749111
# 0            0.104855             3.0  ...              0.969082
#
#   GCN__test_logloss  GCN__train_epochs  GCN__train_lr  GCN__train_lambda  \
# 0          7.875098                100         0.0010              0.010
# 0          1.210218                100         0.0010              0.001
# 0         17.403789                100         0.0001              0.100
# 0          1.258061                100         0.0100             10.000
# 0         17.479501                100         0.0001              0.001
# 0          0.812750                100         0.0100             10.000
# 0          0.821925                100         0.0100              0.100
# 0          0.182065                100         0.0100              1.000
# 0          1.421592                100         0.0010              0.100
# 0          0.799181                100         0.0010              0.001
#
#    GCN__model_in_channels  GCN__model_hidden_channels  GCN__model_num_layers  \
# 0                      16                           4                      4
# 0                      16                           4                      2
# 0                      16                           8                      2
# 0                      16                           4                      1
# 0                      16                           4                      1
# 0                      16                           4                      2
# 0                      16                          16                      4
# 0                      16                           8                      1
# 0                      16                          16                      4
# 0                      16                          16                      1
#
#    GCN__model_dropout  GCN__model_out_channels
# 0                 0.0                        4
# 0                 0.0                        4
# 0                 0.8                        4
# 0                 0.0                        4
# 0                 0.3                        4
# 0                 0.0                        4
# 0                 0.5                        4
# 0                 0.0                        4
# 0                 0.0                        4
# 0                 0.0                        4
#
# [10 rows x 81 columns]

# %%
plot_response_surface1d('p_to_q_ratio', METRIC, results_df)
