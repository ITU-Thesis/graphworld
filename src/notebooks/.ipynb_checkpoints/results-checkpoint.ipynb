# %%
# Imports
import json
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Constants
NSHARDS = 10
RESULTS_DIR = '/tmp/mwe'
LOCALDIR = '/tmp'

ENCODERS = ['GCN', 'GAT', 'GIN']
TRAINING_SCHEMES = ['JL', 'PF', 'URL']
# SSL_METHODS = ['SUBGCON', 'GraphInfoClust','DeepGraphInfomax','MERIT', 'GBT', 'SelfGNNPPR', 'BGRL','GCA', 'PairwiseAttrSim', 'CentralityScoreRanking', 'AttributeMask']
SSL_METHODS = ['AttributeMask']

METRIC = 'test_rocauc_ovr'

# %%
dfs = []
for shard_idx in range(NSHARDS):
  filename = 'results.ndjson-%s-of-%s' % (str(shard_idx).zfill(5), str(NSHARDS).zfill(5))

  with open(f'{RESULTS_DIR}/{filename}', 'r') as f:
    lines = f.readlines()
    records = map(json.loads, lines)
    dfs.append(pd.DataFrame.from_records(records))

# Construct df and remove nans
results_df = pd.concat(dfs)
results_df.drop(['marginal_param', 'fixed_params'], axis=1, inplace=True)
results_df.dropna(axis=0, inplace=True)
del dfs

# %%
def get_cells(dataframe: pd.DataFrame, encoder:str = "", ssl_method:str = "", training_scheme:str = "", other:str = ""):
    cols = [col for col in dataframe if (encoder in col and ssl_method in col 
                                         and training_scheme in col and other in col)]
    return dataframe[cols]

# %%
def plot_learning_curve(df: pd.DataFrame, training_scheme:str, encoder:str, ssl_method:str):
    metrics = ["pretext_losses", "downstream_train_losses", "downstream_val_losses", "downstream_val_tuning_metrics"]
    colors = ["r","g","b","purple"]
    fig, axes = plt.subplots(1, 4, figsize=(15, 2))
    for idx, m in enumerate(metrics):
        cell = get_cells(df, encoder=encoder, training_scheme=training_scheme, other=m).iloc[0,0]
        axes[idx].plot(cell, label=f'{encoder}_{ssl_method}_{training_scheme}_{m}', c=colors[idx])
        
    fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2),
          ncol=4, fancybox=True, shadow=True)
    fig.show()

# %%
for ts in TRAINING_SCHEMES:
    plot_learning_curve(df = results_df, training_scheme = ts, encoder="GCN", ssl_method=SSL_METHODS[0])
# Out:
# []
# [16.691356658935547]
# [0.6603061497211457]
# [1.0]
# [4.956804275512695, 4.946352481842041, 4.940560817718506, 4.932141304016113, 4.925566673278809, 4.9183430671691895, 4.911262035369873, 4.904130458831787, 4.899471759796143, 4.892575740814209, 4.886451721191406, 4.881442546844482, 4.875051021575928, 4.86771297454834, 4.860455513000488, 4.854580879211426, 4.850005626678467, 4.842508792877197, 4.836373329162598, 4.829349040985107, 4.824525356292725, 4.819386005401611, 4.813112258911133, 4.8045783042907715, 4.8010334968566895, 4.796553134918213, 4.789264678955078, 4.780569553375244, 4.773982524871826, 4.769991874694824, 4.763660430908203, 4.759352207183838, 4.753320693969727, 4.745138645172119, 4.73940372467041, 4.733334541320801, 4.731632232666016, 4.727188587188721, 4.7211127281188965, 4.71607780456543, 4.706658363342285, 4.704710006713867, 4.70193338394165, 4.699490070343018, 4.698209285736084, 4.692722320556641, 4.690511703491211, 4.688155174255371, 4.676284313201904, 4.676775932312012]
# [0.6954427361488342, 0.957534670829773, 0.6225508451461792, 0.45441555976867676]
# [16.89584732055664, 16.12657585144043, 0.3465735912322998, 0.0]
# [0.5, 0.5, 0.5, 1.0]
# [4.056168556213379, 4.054856300354004, 4.048875331878662, 4.042501449584961, 4.036758899688721, 4.033627510070801, 4.0289626121521, 4.024506568908691, 4.021543025970459, 4.015948295593262, 4.011352062225342, 4.005354881286621, 4.001816272735596, 3.999850273132324, 3.9931559562683105, 3.9895124435424805, 3.9835031032562256, 3.982743501663208, 3.9772822856903076, 3.9730777740478516, 3.9696033000946045, 3.9661028385162354, 3.961575508117676, 3.957284688949585, 3.9548304080963135, 3.949955463409424, 3.945953130722046, 3.9437835216522217, 3.9377005100250244, 3.9358882904052734, 3.9324817657470703, 3.929192304611206, 3.923707962036133, 3.921530246734619, 3.9201831817626953, 3.9164578914642334, 3.9140255451202393, 3.909780740737915, 3.909377336502075, 3.903172731399536, 3.9021148681640625, 3.8991575241088867, 3.8978326320648193, 3.8940069675445557, 3.893657922744751, 3.888375997543335, 3.886686086654663, 3.88665771484375, 3.8835675716400146, 3.8810644149780273, 3.880394697189331, 3.877368211746216, 3.8772270679473877, 3.873323917388916, 3.8721117973327637, 3.8717257976531982, 3.8700122833251953, 3.869220495223999, 3.8664958477020264, 3.8651652336120605, 3.864229679107666, 3.861766815185547, 3.8612444400787354, 3.8593101501464844, 3.8577024936676025, 3.8562562465667725, 3.85512113571167, 3.8550302982330322, 3.8528430461883545, 3.8526084423065186, 3.8523073196411133, 3.851036310195923, 3.8488714694976807, 3.848567485809326, 3.8480467796325684, 3.84749698638916, 3.846566915512085, 3.845625877380371, 3.8445613384246826, 3.8449082374572754, 3.8439948558807373, 3.843658685684204, 3.840759754180908, 3.8412623405456543, 3.8400282859802246, 3.838848829269409, 3.8394148349761963, 3.838693141937256, 3.837350368499756, 3.836677074432373, 3.8363025188446045, 3.836604595184326, 3.8352229595184326, 3.8345327377319336, 3.8326902389526367, 3.8337137699127197, 3.832872152328491, 3.830552339553833, 3.830646276473999, 3.8304202556610107]
# [0.6928961277008057, 0.8008617162704468, 0.6980676054954529, 0.6955277323722839, 0.7291630506515503, 0.7138711214065552, 0.6768646836280823, 0.6585513353347778, 0.6664891242980957, 0.6756569147109985, 0.667732834815979, 0.6484315991401672]
# [16.816997909545897, 16.048346328735352, 15.805259513854981, 16.485669708251955, 16.375385284423828, 15.025078201293946, 0.41588830947875977, 15.766136169433594, 16.18639373779297, 16.09919853210449, 15.071504974365235, 0.3465735912322998]
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.9, 0.5, 0.5, 0.5, 0.5, 1.0]

# %%
for ts in TRAINING_SCHEMES:
    plot_learning_curve(df = results_df, training_scheme = ts, encoder="GAT", ssl_method=SSL_METHODS[0])

# %%
for ts in TRAINING_SCHEMES:
    plot_learning_curve(df = results_df, training_scheme = ts, encoder="GIN", ssl_method=SSL_METHODS[0])
